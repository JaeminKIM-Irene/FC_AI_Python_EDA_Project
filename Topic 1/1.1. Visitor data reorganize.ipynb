# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from utils import Utils

ut = Utils()

# %%
asia_data = pd.read_excel('../data/국민 해외관광객 주요 목적지별 통계(202305).xlsx', sheet_name='Asia')
europe_data = pd.read_excel('../data/국민 해외관광객 주요 목적지별 통계(202305).xlsx', sheet_name='Europe')
africa_data = pd.read_excel('../data/국민 해외관광객 주요 목적지별 통계(202305).xlsx', sheet_name='Africa')
america_data = pd.read_excel('../data/국민 해외관광객 주요 목적지별 통계(202305).xlsx', sheet_name='America')
oceania_data = pd.read_excel('../data/국민 해외관광객 주요 목적지별 통계(202305).xlsx', sheet_name='Oceania')

# %%
# 아시아 데이터 column명 바꾸기
asia_data.columns = ['Year', 'month', '법무부_명수', '법무부_전년대비', '일본_명수', '일본_전년대비', '중국_명수', '중국_전년대비', 
                    '베트남_명수', '베트남_전년대비', '태국_명수', '태국_전년대비', '필리핀_명수', '필리핀_전년대비', 
                    '홍콩_명수', '홍콩_전년대비', '대만_명수', '대만_전년대비', '마카오_명수', '마카오_전년대비',
                    '싱가폴_명수', '싱가폴_전년대비', '말레이시아_명수', '말레이시아_전년대비', '인도네시아_명수', '인도네시아_전년대비',
                    '캄보디아_명수', '캄보디아_전년대비', '라오스_명수', '라오스_전년대비', '튀르키예_명수', '튀르키예_전년대비', '인도_명수', '인도_전년대비', 
                    '몽골_명수', '몽골_전년대비', '미얀마_명수', '미얀마_전년대비', '이스라엘_명수', '이스라엘_전년대비',
                    '몰디브_명수', '몰디브_전년대비', '스리랑카_명수', '스리랑카_전년대비', '사이프러스_명수', '사이프러스_전년대비', 
                     '부탄_명수', '부탄_전년대비', '요르단_명수', '요르단_전년대비', '네팔_명수', '네팔_전년대비', '예멘_명수', '예멘_전년대비']
org_asia_data = asia_data.iloc[2:-1, :]
org_asia_data
# Out:
#       Year month    법무부_명수  법무부_전년대비    일본_명수     일본_전년대비    중국_명수   중국_전년대비  \
# 2    2004년    1월    793478       NaN   164785         NaN   186246       NaN
# 3      NaN    2월    670447       NaN   142718         NaN   215373       NaN
# 4      NaN    3월    587629       NaN   112516         NaN   190382       NaN
# 5      NaN    4월    642413       NaN   120427         NaN   223062       NaN
# 6      NaN    5월    680185       NaN   115659         NaN   202592       NaN
# ..     ...   ...       ...       ...      ...         ...      ...       ...
# 261  2019년    누계  28714247  0.000636  5584597   -0.259234  4346567  0.036924
# 262  2020년    누계   4276006 -0.851084   487939   -0.912628        0       NaN
# 263  2021년    누계   1222541 -0.714093    18947   -0.961169        0       NaN
# 264  2022년    누계   6554031  4.360991  1012751   52.451787        0       NaN
# 265  2023년    누계   8159513  7.709519  2583383  100.808197        0       NaN
#
#       베트남_명수  베트남_전년대비  ... 사이프러스_명수 사이프러스_전년대비 부탄_명수   부탄_전년대비 요르단_명수  \
# 2        NaN       NaN  ...      NaN        NaN   NaN       NaN    NaN
# 3        NaN       NaN  ...      NaN        NaN   NaN       NaN    NaN
# 4        NaN       NaN  ...      NaN        NaN   NaN       NaN    NaN
# 5        NaN       NaN  ...      NaN        NaN   NaN       NaN    NaN
# 6        NaN       NaN  ...      NaN        NaN   NaN       NaN    NaN
# ..       ...       ...  ...      ...        ...   ...       ...    ...
# 261  4290802  0.248994  ...      NaN        NaN  1408  0.410822  20322
# 262   840041 -0.804223  ...        0        NaN   142 -0.899148   6825
# 263    32500 -0.961311  ...        0        NaN     0       NaN   1031
# 264   769167       NaN  ...        0        NaN     0       NaN      0
# 265  1317833       NaN  ...        0        NaN     0       NaN      0
#
#      요르단_전년대비  네팔_명수   네팔_전년대비 예멘_명수 예멘_전년대비
# 2         NaN    NaN       NaN   NaN     NaN
# 3         NaN    NaN       NaN   NaN     NaN
# 4         NaN    NaN       NaN   NaN     NaN
# 5         NaN    NaN       NaN   NaN     NaN
# 6         NaN    NaN       NaN   NaN     NaN
# ..        ...    ...       ...   ...     ...
# 261  0.356156  31108 -0.164168   NaN     NaN
# 262 -0.664157   6944 -0.776778     0     NaN
# 263 -0.848938      0       NaN     0     NaN
# 264       NaN      0       NaN   NaN     NaN
# 265       NaN      0       NaN   NaN     NaN
#
# [264 rows x 54 columns]

# %%
# 유럽 데이터 column명 바꾸기
europe_data.columns = ['Year', 'month', '법무부_명수', '법무부_전년대비', '스페인_명수', '스페인_전년대비', '독일_명수', '독일_전년대비', 
                    '오스트리아_명수', '오스트리아_전년대비', '영국_명수', '영국_전년대비', '슬로베니아_명수', '슬로베니아_전년대비', 
                    '러시아_명수', '러시아_전년대비', '보스니아_명수', '보스니아_전년대비', '핀란드_명수', '핀란드_전년대비',
                    '슬로바키아_명수', '슬로바키아_전년대비', '북마케도니아_명수', '북마케도니아_전년대비', '세르비아_명수', '세르비아_전년대비',
                    '스웨덴_명수', '스웨덴_전년대비', '리히텐슈타인_명수', '리히텐슈타인_전년대비', '조지아_명수', '조지아',
                    '산마리노_명수', '산마리노_전년대비']
org_europe_data = europe_data.iloc[2:-1, :]
org_europe_data
# Out:
#       Year month    법무부_명수  법무부_전년대비  스페인_명수  스페인_전년대비   독일_명수   독일_전년대비  \
# 2    2004년    1월    793478       NaN     NaN       NaN    7414       NaN
# 3      NaN    2월    670447       NaN     NaN       NaN    7506       NaN
# 4      NaN    3월    587629       NaN     NaN       NaN    8974       NaN
# 5      NaN    4월    642413       NaN     NaN       NaN    8172       NaN
# 6      NaN    5월    680185       NaN     NaN       NaN   11376       NaN
# ..     ...   ...       ...       ...     ...       ...     ...       ...
# 261  2019년    누계  28714247  0.000636  630797  0.295625  342305 -0.043739
# 262  2020년    누계   4276006 -0.851084  121931 -0.806703   61675 -0.819824
# 263  2021년    누계   1222541 -0.714093   37692 -0.690874   28773 -0.533474
# 264  2022년    누계   6554031  4.360991  180610  3.791733  123185  3.281271
# 265  2023년    누계   8159513  7.709519       0       NaN   53209  2.422021
#
#     오스트리아_명수 오스트리아_전년대비  ... 세르비아_명수  세르비아_전년대비 스웨덴_명수 스웨덴_전년대비 리히텐슈타인_명수  \
# 2       1518        NaN  ...     NaN        NaN    579      NaN         5
# 3       1511        NaN  ...     NaN        NaN   1438      NaN         8
# 4       1783        NaN  ...     NaN        NaN    885      NaN        21
# 5       3006        NaN  ...     NaN        NaN    818      NaN         4
# 6       4875        NaN  ...     NaN        NaN   1849      NaN        17
# ..       ...        ...  ...     ...        ...    ...      ...       ...
# 261   324596   0.014578  ...    2657  -0.197523    NaN      NaN       162
# 262    36646  -0.887103  ...   34.04  -0.987189      0      NaN         0
# 263     4980  -0.864105  ...      32  -0.059929      0      NaN         0
# 264    61830  11.415663  ...      99    2.09375      0      NaN         0
# 265    60803   7.737319  ...     290  40.428571    NaN      NaN       NaN
#
#     리히텐슈타인_전년대비 조지아_명수       조지아 산마리노_명수 산마리노_전년대비
# 2           NaN    NaN       NaN     NaN       NaN
# 3           NaN    NaN       NaN     NaN       NaN
# 4           NaN    NaN       NaN     NaN       NaN
# 5           NaN    NaN       NaN     NaN       NaN
# 6           NaN    NaN       NaN     NaN       NaN
# ..          ...    ...       ...     ...       ...
# 261    0.109589  16642  0.253351     NaN       NaN
# 262         NaN      0       NaN       0       NaN
# 263         NaN      0       NaN       0       NaN
# 264         NaN      0       NaN       0       NaN
# 265         NaN    NaN       NaN     NaN       NaN
#
# [264 rows x 34 columns]

# %%
# 아프리카 데이터 column명 바꾸기
africa_data.columns = ['Year', 'month', '법무부_명수', '법무부_전년대비', '남아프리카공화국_명수', '남아프리카공화국_전년대비',
                       '모리셔스_명수', '모리셔스_전년대비', '스와질랜드_명수', '스와질랜드_전년대비',
                    '세이쉘_명수', '세이쉘_전년대비', '짐바브웨_명수', '짐바브웨_전년대비', 
                    '우간다_명수', '우간다_전년대비', '시에라리온_명수', '시에라리온_전년대비']
org_africa_data = africa_data.iloc[2:-1, :]
org_africa_data
# Out:
#       Year month    법무부_명수  법무부_전년대비 남아프리카공화국_명수 남아프리카공화국_전년대비 모리셔스_명수  \
# 2    2004년    1월    793478       NaN        1582           NaN     NaN
# 3      NaN    2월    670447       NaN        1214           NaN     NaN
# 4      NaN    3월    587629       NaN         883           NaN     NaN
# 5      NaN    4월    642413       NaN         791           NaN     NaN
# 6      NaN    5월    680185       NaN         784           NaN     NaN
# ..     ...   ...       ...       ...         ...           ...     ...
# 261  2019년    누계  28714247  0.000636       19947     -0.087845    7072
# 262  2020년    누계   4276006 -0.851084        4222     -0.788339  776.03
# 263  2021년    누계   1222541 -0.714093        1346     -0.681194     136
# 264  2022년    누계   6554031  4.360991        5103      2.791233    1171
# 265  2023년    누계   8159513  7.709519        3301      1.814152    1302
#
#      모리셔스_전년대비 스와질랜드_명수 스와질랜드_전년대비  세이쉘_명수  세이쉘_전년대비 짐바브웨_명수 짐바브웨_전년대비 우간다_명수  \
# 2          NaN      NaN        NaN       4       NaN     NaN       NaN    NaN
# 3          NaN      NaN        NaN       -       NaN     NaN       NaN    NaN
# 4          NaN      NaN        NaN       -       NaN     NaN       NaN    NaN
# 5          NaN      NaN        NaN       -       NaN     NaN       NaN    NaN
# 6          NaN      NaN        NaN       2       NaN     NaN       NaN    NaN
# ..         ...      ...        ...     ...       ...     ...       ...    ...
# 261  -0.018323     2109   0.037894    1007 -0.298258       0       NaN      0
# 262  -0.890267   388.01  -0.816022  127.04 -0.873843       0       NaN      0
# 263  -0.824749      303  -0.219092      18 -0.858312       0       NaN      0
# 264   7.610294      813   1.683168      54        17       0       NaN      0
# 265  10.128205      403   0.291667       0       NaN     NaN       NaN    NaN
#
#     우간다_전년대비 시에라리온_명수 시에라리온_전년대비
# 2        NaN      NaN        NaN
# 3        NaN      NaN        NaN
# 4        NaN      NaN        NaN
# 5        NaN      NaN        NaN
# 6        NaN      NaN        NaN
# ..       ...      ...        ...
# 261      NaN      NaN        NaN
# 262      NaN      NaN        NaN
# 263      NaN      NaN        NaN
# 264      NaN      NaN        NaN
# 265      NaN      NaN        NaN
#
# [264 rows x 18 columns]

# %%
# 아메리카 데이터 column명 바꾸기
america_data.columns = ['Year', 'month', '법무부_명수', '법무부_전년대비', '미국_명수', '미국_전년대비',
                        '캐나다_명수', '캐나다_전년대비', '브라질_명수', '브라질_전년대비',
                        '도미니카공화국_명수', '도미니카공화국_전년대비', '자메이카_명수', '자메이카_전년대비', 
                        '과테말라_명수', '과테말라_전년대비', '칠레_명수', '칠레_전년대비', '코스타리카_명수', '코스타리카_전년대비',
                       '파나마_명수', '파나마_전년대비', '페루_명수', '페루_전년대비', '멕시코_명수', '멕시코_전년대비', 
                       '에콰도르_명수', '에콰도르_전년대비']
org_america_data = america_data.iloc[2:-1, :]
org_america_data
# Out:
#       Year month    법무부_명수  법무부_전년대비    미국_명수   미국_전년대비  캐나다_명수  캐나다_전년대비  \
# 2    2004년    1월    793478       NaN    63341       NaN   11243       NaN
# 3      NaN    2월    670447       NaN    47191       NaN    7927       NaN
# 4      NaN    3월    587629       NaN    43664       NaN    9243       NaN
# 5      NaN    4월    642413       NaN    40831       NaN   11723       NaN
# 6      NaN    5월    680185       NaN    52600       NaN   14088       NaN
# ..     ...   ...       ...       ...      ...       ...     ...       ...
# 260  2018년    누계  28695983  0.085579  2210597 -0.053212  253236 -0.160013
# 261  2019년    누계  28714247  0.000636  2298279  0.039664  266767  0.053432
# 262  2020년    누계   4276006 -0.851084   439286 -0.808863   33861 -0.873069
# 263  2021년    누계   1222541 -0.714093   202711 -0.538544   15880 -0.531024
# 264  2022년    누계   6554031  4.360991   919796  3.537475   78326  3.932368
#
#     브라질_명수  브라질_전년대비  ... 코스타리카_명수 코스타리카_전년대비 파나마_명수  파나마_전년대비  페루_명수  \
# 2     2335       NaN  ...      NaN        NaN    NaN       NaN   4641
# 3     2515       NaN  ...      NaN        NaN    NaN       NaN    NaN
# 4     1804       NaN  ...      NaN        NaN    NaN       NaN    NaN
# 5     1379       NaN  ...      NaN        NaN    NaN       NaN    NaN
# 6     1668       NaN  ...      NaN        NaN    NaN       NaN    NaN
# ..     ...       ...  ...      ...        ...    ...       ...    ...
# 260  33845 -0.212852  ...     4879  -0.060104   6180  0.060944  32133
# 261  39321  0.161796  ...     4933   0.011068    NaN       NaN      0
# 262      0       NaN  ...  1506.02  -0.694705      0       NaN      0
# 263      0       NaN  ...      858  -0.430286      0       NaN      0
# 264      0       NaN  ...     2462   1.869464      0       NaN      0
#
#       페루_전년대비  멕시코_명수  멕시코_전년대비 에콰도르_명수 에콰도르_전년대비
# 2         NaN     NaN       NaN     NaN       NaN
# 3         NaN     NaN       NaN     NaN       NaN
# 4         NaN     NaN       NaN     NaN       NaN
# 5         NaN     NaN       NaN     NaN       NaN
# 6         NaN     NaN       NaN     NaN       NaN
# ..        ...     ...       ...     ...       ...
# 260  0.095829  122307  0.146077    5367 -0.042633
# 261       NaN  120424 -0.015396       0       NaN
# 262       NaN   35305 -0.706828       0       NaN
# 263       NaN   31311 -0.113128       0       NaN
# 264       NaN   61609  0.967647       0       NaN
#
# [263 rows x 28 columns]

# %%
oceania_data.iloc[0, :]
# Out:
# 국민 해외관광객(오세아니아)                          NaN
# Unnamed: 1                               NaN
# Unnamed: 2                           법무부・KTO
# Unnamed: 3                               NaN
# Unnamed: 4                                호주
# Unnamed: 5                         Australia
# * Northern Mariana Is(Saipan)     북마리아나(사이판)
# Unnamed: 7                               NaN
# Unnamed: 8                            괌(미국령)
# Unnamed: 9                              Guam
# Unnamed: 10                             뉴질랜드
# Unnamed: 11                      New Zealand
# Unnamed: 12                              팔라우
# Unnamed: 13                            Palau
# Unnamed: 14                               피지
# Unnamed: 15                             Fiji
# Name: 0, dtype: object

# %%
# 아프리카 데이터 column명 바꾸기
oceania_data.columns = ['Year', 'month', '법무부_명수', '법무부_전년대비', '호주_명수', '호주_전넌대비',
                        '북마리아나(사이판)_명수', '북마리아나(사이판)_전넌대비', '괌_명수', '괌_전넌대비',
                        '뉴질랜드_명수', '뉴질랜드_전넌대비', '팔라우_명수', '팔라우_전넌대비', 
                        '피지_명수', '피지_전넌대비']
org_oceania_data = oceania_data.iloc[2:-1, :]
org_oceania_data
# Out:
#       Year month    법무부_명수  법무부_전년대비   호주_명수    호주_전넌대비 북마리아나(사이판)_명수  \
# 2    2004년    1월    793478       NaN   25870        NaN          7825
# 3      NaN    2월    670447       NaN   19350        NaN          6434
# 4      NaN    3월    587629       NaN   15190        NaN          4228
# 5      NaN    4월    642413       NaN   14130        NaN          4827
# 6      NaN    5월    680185       NaN   16130        NaN          4294
# ..     ...   ...       ...       ...     ...        ...           ...
# 260  2018년    누계  28695983  0.083012  287990  -0.047053        240577
# 261  2019년    누계  28714247  0.000636  280480  -0.026077        123058
# 262  2020년    누계   4276006 -0.851084   53520  -0.809184             8
# 263  2021년    누계   1222541 -0.714093    2060   -0.96151          6783
# 264  2022년    누계   6554031  4.360991   72510  34.199029         74613
#
#     북마리아나(사이판)_전넌대비    괌_명수     괌_전넌대비 뉴질랜드_명수  뉴질랜드_전넌대비 팔라우_명수  팔라우_전넌대비  \
# 2          0.040915     NaN        NaN   18575        NaN     76       NaN
# 3         -0.151796     NaN        NaN   10941        NaN     68       NaN
# 4         -0.010425     NaN        NaN    8274        NaN     56       NaN
# 5         -0.019036     NaN        NaN    7077        NaN     71       NaN
# 6         -0.016861     NaN        NaN    6696        NaN    966       NaN
# ..              ...     ...        ...     ...        ...    ...       ...
# 260        -0.28136  746986   0.090128   87853  -0.036361  14347  0.206137
# 261       -0.488488  753357   0.008529   88431   0.006579  11884 -0.171674
# 262       -0.999935  124181  -0.835163   26383  -0.701654   2702 -0.772635
# 263         846.875    8002  -0.935562     476  -0.981958     25 -0.990748
# 264              10  193407  23.169833   14343  29.132353    227      8.08
#
#     피지_명수    피지_전넌대비
# 2     NaN        NaN
# 3     NaN        NaN
# 4     NaN        NaN
# 5     NaN        NaN
# 6     NaN        NaN
# ..    ...        ...
# 260  8176  -0.078345
# 261  6806  -0.167564
# 262   548  -0.919483
# 263    51  -0.906934
# 264   709  12.901961
#
# [263 rows x 16 columns]

# %%
org_asia_data.to_csv('../data/visitor_kor/asia_data_kor.csv', encoding='utf-8-sig', index=False)
org_europe_data.to_csv('../data/visitor_kor/europe_data_kor.csv', encoding='utf-8-sig', index=False)
org_africa_data.to_csv('../data/visitor_kor/africa_data_kor.csv', encoding='utf-8-sig', index=False)
org_america_data.to_csv('../data/visitor_kor/america_data_kor.csv', encoding='utf-8-sig', index=False)
org_oceania_data.to_csv('../data/visitor_kor/oceania_data_kor.csv', encoding='utf-8-sig', index=False)
